# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
# %matplotlib inline
# 이미지 불러오기
img = mpimg.imread('image.png')

# 이미지 표시
plt.imshow(img)
plt.axis('off')  # 축 제거
plt.show()
plt.close
# Out:
# <function matplotlib.pyplot.close(fig: "None | int | str | Figure | Literal['all']" = None) -> 'None'>

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.size
# Out:
# 1068972

# %%
blue=img[:,:,0]
blue=img[:,:,1]
blue=img[:,:,2]

# %%
def show_img(image_path,tile='image'):
    image=cv2.imread(image_path)
    if image is None:
        print("오류")
        return
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
    plt.show()
    plt.close()

# %%
path="image.png"

# %%
show_img(path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 show_img(path)
#
# Cell In[25], line 7, in show_img(image_path, tile)
#       5     return
#       6 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# ----> 7 plt.show(img_rgb)
#       8 plt.tile(tile)
#       9 plt.show()
#
# File c:\anaconda\envs\studyOpencv\lib\site-packages\matplotlib\pyplot.py:612, in show(*args, **kwargs)
#     568 """
#     569 Display all open figures.
#     570
#    (...)
#     609 explicitly there.
#     610 """
#     611 _warn_if_gui_out_of_main_thread()
# --> 612 return _get_backend_mod().show(*args, **kwargs)
#
# File c:\anaconda\envs\studyOpencv\lib\site-packages\matplotlib_inline\backend_inline.py:98, in show(close, block)
#      95 show._to_draw = []
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
# ---> 98 if close and Gcf.get_all_fig_managers():
#      99     matplotlib.pyplot.close('all')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
